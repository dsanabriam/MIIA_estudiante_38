# %% [markdown]
# <img src="Archivos/miia.jpg" width=800x>
#
# # Laboratorio 1
#
# ## Desarrollo de una herramienta analítica usando solo Python
#
# Este laboratorio busca evaluar las habilidades relacionadas con la primera parte del curso, correspondiente a las primeras tres semanas. Este enunciado estará disponible desde la semana 2 y deberá entregarse al final de la semana 4 en el enlace correspondiente. Su desarrollo corresponde al 30% de la calificación total del curso.
#
# Esta actividad responde directamente al segundo objetivo del curso:
# * Implementar una herramienta analítica que permita responder una pregunta de negocio para un problema sencillo de analítica de datos, utilizando únicamente algorítmica básica en Python.
#
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
# 1. Leer datos desde archivos.
# 2. Almacenar datos en  estructuras de Python.
# 3. Crear y llamar funciones correctamente.
# 4. Implementar condicionales diferenciando *if*, *elif* y *else*
# 5. Implementar ciclos diferenciando el propósito de *for* y *while*
# 6. Importar paquetes y utilizar sus funciones.
#
# **NOTAS:**
# - Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito completo de la actividad, y puedas desarrollar tu solución apuntando a él desde el comienzo.

# %% [markdown]
# ## Contexto: exploración del potencial para asignar becas Uniandes
# La Universidad de los Andes se ha caracterizado por su compromiso con la generación de impacto en la sociedad a través de diferentes programas de becas. Programas como Quiero Estudiar, o Ser Pilo Paga, entre otros, han sido revolucionarios, al permitir que estudiantes de bajos recursos puedan acceder a una de las universidades privadas más importantes del país.
#
# Actualmente, la Universidad quiere evaluar el potencial impacto que tendrían algunos programas de *acción afirmativa* para asignación de becas, con base en información demográfica que ha obtenido a través de encuestas. Se cuenta con información respecto a la edad, género, estado civil, estrato socio-económico, región de proveniencia, desempeño académico y nivel de escolaridad de las personas que han respondido encuestas. Los encargados de diseñar el programa saben que utilizar criterios basados en este tipo de variables es un tema sensible, pero es necesario si se quieren focalizar las oportunidades en poblaciones menos representadas.
#
# El objetivo de este laboratorio es crear una herramienta computacional que permita a un tomador de decisiones explorar qué efecto podría tener el uso de diferentes reglas para seleccionar la población que sería beneficiaria de las becas. Puntualmente, se espera que, dadas unas reglas de selección (ej.: pertenecer a cierta región, rango de edad, etc.), la herramienta ofrezca información sobre la población potencialmente beneficiada, de forma que exista un sustento al momento de definir las reglas de selección.

# %% [markdown]
# ## 1. Obtención e inspección de archivos
#
# Los datos de encuestas fueron obtenidos como parte de un trabajo de campo, y por limitaciones tecnológicas, solo se cuenta con la información en archivos de texto plano. Cada archivo corresponde a una de las variables antes mencionadas y se puede garantizar que todos relacionan a las personas encuestadas en el mismo orden (i.e., la primera línea de todos los archivos corresponde a datos de la primera persona encuestada, la segunda línea a la segunda persona, etc.).
#
# Los archivos con los que se cuenta son:
# * *edades.txt*: un archivo ordenado con las edades de cada persona de la población encuestada
# * *género.txt*: un archivo ordenado con el género de cada persona de la población encuestada
# * *estado_civil.txt*: un archivo ordenado con el estado civil de cada persona de la población encuestada
# * *escolaridad.txt*: un archivo ordenado con el nivel de escolaridad de cada persona de la población encuestada
# * *estrato.txt*: un archivo ordenado con el estrato socio-económico de cada persona de la población encuestada
# * *region.txt*: un archivo ordenado con la región de proveniencia de cada persona de la población encuestada

# %% [markdown]
# **Misión 1**
#
# Poner en variables de Python la información que está en los archivos listados arriba.
#
# * *Versión base*: escribe línea a línea el código necesario para poner en variables de Python la información de cada uno de los archivos.
#
# * *Milla extra*: escribe una función que sea capaz de hacer lo anterior para un archivo y úsala en un ciclo para automatizar la lectura de los diferentes archivos.

# %%
# Unificación Archivos#############################################################
'version base'

def read_str (t):
    
    with open(t,mode="r", encoding="utf-8") as f:
        f = f.read()
        f = f.splitlines()        
    return f
 
 
def read_float (t):
    
    with open(t,mode="r", encoding="utf-8") as f:
        f = f.read()
        f = f.splitlines()
        f = [float(i) for i in f]
    return f
  
txt = ["edad", "escolaridad", "estado_civil", "estrato", "genero", "promedio", "region"]
 
 
for i in range(len(txt)):
    if txt[i] == "edad":
        exec(txt[i]+'{} = read_float ("./Archivos/"+ txt[i] +".txt")'.format(i))
    elif txt[i] == "promedio":
        exec(txt[i]+'{} = read_float ("./Archivos/"+ txt[i] +".txt")'.format(i))
    elif txt[i] == "estrato":
        exec(txt[i]+'{} = read_float ("./Archivos/"+ txt[i] +".txt")'.format(i))
    else:
        exec(txt[i]+'{} = read_str ("./Archivos/"+ txt[i] +".txt")'.format(i))
 
 
datos2 = {"edad" : list(edad0),
         "escolaridad" : list(escolaridad1),
         "estado_civil" : list(estado_civil2),
         "estrato" : list(estrato3),
         "genero" : list(genero4),
         "promedio" : list(promedio5),
         "region" : list(region6)}

#print(datos2)

alg={}
for i in range(len(edad0)):
    exec('alg["Estudiante_{0}"] ='.format(i+1)+' {'+'"edad":{0},"escolaridad":"{1}","estado_civil":"{2}","estrato":{3},"genero":"{4}","promedio":{5},"region":"{6}"'.format(edad0[i],escolaridad1[i], estado_civil2[i],
                                                     estrato3[i],genero4[i],promedio5[i],region6[i])+"}")

print(alg)
# Out:
# {'Estudiante_1': {'edad': 36.0, 'escolaridad': 'Secundaria', 'estado_civil': 'casada', 'estrato': 5.0, 'genero': 'masculino', 'promedio': 2.4, 'region': 'Andina'}, 'Estudiante_2': {'edad': 66.0, 'escolaridad': 'Profesional', 'estado_civil': 'divorciada', 'estrato': 1.0, 'genero': 'masculino', 'promedio': 0.9, 'region': 'Andina'}, 'Estudiante_3': {'edad': 24.0, 'escolaridad': 'Secundaria', 'estado_civil': 'divorciada', 'estrato': 3.0, 'genero': 'femenino', 'promedio': 3.2, 'region': 'Pacifica'}, 'Estudiante_4': {'edad': 55.0, 'escolaridad': 'Secundaria', 'estado_civil': 'casada', 'estrato': 3.0, 'genero': 'masculino', 'promedio': 2.1, 'region': 'Pacifica'}, 'Estudiante_5': {'edad': 26.0, 'escolaridad': 'Secundaria', 'estado_civil': 'divorciada', 'estrato': 2.0, 'genero': 'otro', 'promedio': 2.1, 'region': 'Orinoquia'}, 'Estudiante_6': {'edad': 69.0, 'escolaridad': 'Secundaria', 'estado_civil': 'divorciada', 'estrato': 3.0, 'genero': 'no binario', 'promedio': 2.0, 'region': 'Caribe'}, 
# ...

# %% [markdown]
# # **Misión 2**
#
# Reportar las principales características en los datos.
# * *Versión base*: utilizar métricas básicas como conteos o promedios por categorías en los datos.
# * *Milla extra*: utilizar visualizaciones simples como diagramas de barras, de pastel u otros.

# %%
# código
import statistics
import numpy as np

count_datos=len(edad0)

print ("La base de datos cuenta con : " + str(count_datos) + " registros")

median_edad=statistics.median(edad0)
median_promedio=statistics.median(promedio5)
median_estrato=statistics.median(estrato3)
print ("Mediana de la edad: " + str(median_edad) + " Mediana Promedio: "+str(median_promedio) + " Mediana estrato: "+str(median_estrato))

mean_edad=statistics.mean(edad0)
mean_promedio=statistics.mean(promedio5)
mean_estrato=statistics.mean(estrato3)
print ("Media de la edad: " + str(mean_edad) + " Media Promedio: "+str(mean_promedio) + " Media estrato: "+str(mean_estrato))

st_edad=statistics.stdev(edad0)
st_promedio=statistics.stdev(promedio5)
st_estrato=statistics.stdev(estrato3)
print ("Desviación estandar de la edad: " + str(round(st_edad,3)) + " Desviación estandar Promedio: "+str(round(st_promedio,3)) + " Desviación estandar estrato: "+str(round(st_promedio,3)))

import matplotlib.pyplot as plt
#Edad vs Promedio
fig, ax = plt.subplots()
ax.scatter(edad0, promedio5)
ax.set_xscale('linear')                               # Establecemos una escala lineal para el eje x.
ax.set_yscale('linear')                               # Establecemos una escala lineal para el eje y.
ax.set_title('Gráfico de dispersión Edad vs. Promedio')                 # Definimos un título para la visualización.
ax.grid(True)                                         # Agregamos una grilla al gráfico.
plt.show()


#Histograma de conteo por causales Edad
plt.style.use('ggplot')
plt.hist(edad0, color="darkorange")
plt.title("Frecuencia según edad")
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales escolaridad
plt.style.use('ggplot')
plt.hist(escolaridad1, color="red")
plt.title("Frecuencia según grado de escolaridad")
plt.xlabel('Escolaridad')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales estado civil
plt.style.use('ggplot')
plt.hist(estado_civil2, color="green")
plt.title("Frecuencia según estado civil")
plt.xlabel('Estado civil')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales estrato
plt.style.use('ggplot')
plt.hist(estrato3, color="black", rwidth=1.5)
plt.title("Frecuencia según estrato")
plt.xlabel('Estrato')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales genero
plt.style.use('ggplot')
plt.hist(genero4, color="blue", rwidth=1.5)
plt.title("Frecuencia según género")
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por promedio
plt.style.use('ggplot')
plt.hist(promedio5, color="red", rwidth=1.5)
plt.title("Frecuencia según promedio")
plt.xlabel('Promedio')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por promedio
plt.style.use('ggplot')
plt.hist(region6, color="blueviolet", rwidth=1.5)
plt.title("Frecuencia según Región")
plt.xlabel('Región')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# La base de datos cuenta con : 500 registros
# Mediana de la edad: 49.0 Mediana Promedio: 2.7 Mediana estrato: 2.0
# Media de la edad: 48.748 Media Promedio: 2.6212 Media estrato: 2.308
# Desviación estandar de la edad: 18.613 Desviación estandar Promedio: 1.117 Desviación estandar estrato: 1.117

# %% [markdown]
# ## 2. Abordaje de la pregunta de negocio
#
# El comité encargado de diseñar el programa de becas ha tenido dificultades para llegar a acuerdos. Algunos piensan que el criterio principal de selección debería ser respecto a lo económico y académico, sin importar otras características personales, mientras que otros piensan que considerar estas características es, de hecho, parte del espíritu del programa.
#
# * El primer grupo sugiere que se deben tomar en orden ascendente los estratos y elegir, en cada uno de ellos, al 2% de personas con promedio académico superior en esa sub-población, hasta que se agoten las becas disponibles. En caso de quedar becas disponibles al final del proceso, se repite el mismo esquema, considerando que ya no se tienen en cuenta las personas que hayan sido elegidas en rondas anteriores.
#
# * El segundo grupo sugiere que los recibidores de becas deben estar igualmente distribuidos entre las diferentes regiones y generos, considerando, por supuesto, que para cada una de esas sub-poblaciones, las personas elegidas sean las de mejores promedios académicos.
#
# Dado que las diferencias entre estos grupos obedecen a su entendimiento particular del problema, el presidente del comité propone utilizar los datos disponibles de las encuestas, sugiriendo que se analice qué características tendría la población de elegidos bajo cada uno de los dos criterios expuestos.

# %% [markdown]
# **Misión 3**
#
# Defina la pregunta de negocio y la pregunta de *analytics* para esta situación.

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

pregunta_negocio = '¿Qué características debe cumplir la población de elegidos para el programa de asignación de becas? '

pregunta_analytics = '¿Cúal es el modelo a aplicar para definir la metodologia de asignación de becas, respetando los criterios indicados por el comité?'

# %% [markdown]
# **Misión 4**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *primer grupo* mencionado arriba.

# %%
#Algoritmo de asignación de becas según estrato y ordenamiento por promedio###

becas=100 # numero de becas a asignar
estratos=[]
for (k,v) in alg.items():
    if not v['estrato'] in estratos:estratos.append(v['estrato']) 
per=[]
#con este ciclo se hace el conteo de registros por estrato y calcula el 2%
for j in range(len(estratos)):
    exec('Estrato{0}=dict(filter(lambda item: (item[1]["estrato"]==({0})), alg.items()))'.format((j+1))) 
    exec('Estrato{0}=dict(sorted(Estrato{0}.items(), key =lambda x: -x[1]["promedio"]))'.format((j+1)))
    filtered_dict = len(dict(filter(lambda item: (item[1]['estrato']==(j+1)), alg.items()))) #estrato 1
    per.append(int(filtered_dict*0.02))
    print ("Estrato "+ str(j+1)+" tiene: "+str(filtered_dict)+" registros")
    print (per)

dic_estrato={}
while becas>0:
    for j in range(len(estratos)):
        n_registros=per[j]
        for i in range(n_registros): 
            exec('key=list(Estrato{0}.keys())[0]'.format(j+1))
            exec('valores=list(Estrato{0}.values())[0]'.format(j+1))
            exec('dic_estrato["{0}"]={1}'.format(key,valores))
            exec('Estrato{0}.pop("{1}")'.format(j+1,key))
            becas=becas-1
            if becas<1: break
        if becas<1: break
            
dic_estrato
# Out:
# Estrato 1 tiene: 111 registros
# [2]
# Estrato 2 tiene: 185 registros
# [2, 3]
# Estrato 3 tiene: 156 registros
# [2, 3, 3]
# Estrato 4 tiene: 35 registros
# [2, 3, 3, 0]
# Estrato 5 tiene: 13 registros
# [2, 3, 3, 0, 0]
# {'Estudiante_377': {'edad': 69.0,
#   'escolaridad': 'Secundaria',
#   'estado_civil': 'soltera',
#   'estrato': 1.0,
#   'genero': 'masculino',
#   'promedio': 5.0,
#   'region': 'Pacifica'},
#  'Estudiante_163': {'edad': 47.0,
#   'escolaridad': 'Secundaria',
#   'estado_civil': 'casada',
#   'estrato': 1.0,
#   'genero': 'masculino',
#   'promedio': 4.9,
#   'region': 'Andina'},
#  'Estudiante_244': {'edad': 59.0,
#   'escolaridad': 'Secundaria',
#   'estado_civil': 'divorciada',
#   'estrato': 2.0,
#   'genero': 'femenino',
#   'promedio': 5.0,
#   'region': 'Caribe'},
#  'Estudiante_8': {'edad': 54.0,
#   'escolaridad': 'Secundaria',
#   'estado_civil': 'casada',
#   'estrato': 2.0,
#   'genero': 'femenino',
#   'promedio': 4.9,
#   'region': 'Andina'},
# ...

# %% [markdown]
# **Misión 5**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *segundo grupo* mencionado arriba.

# %%
# Asignación de Becas en función de la region, genero y promedio bajo el concepto de equidad por grupo#
becas=100
global dic_copia
dic_copia=dict(alg)

def lista_grupos ():
    lista_dist=[]
    for (k,v) in dic_copia.items():
        region=v['region']
        genero=v['genero']
        if not [region, genero] in lista_dist:lista_dist.append([region, genero]) 
    
    return lista_dist

            
dic_grupo={}
while becas>0:
    global lista_dist
    lista_dist=lista_grupos()
    
    for j in range(len(lista_dist)):
        region=lista_dist[j][0]
        genero=lista_dist[j][1]
        exec('Grupo{0}=dict(filter(lambda item: ((item[1]["region"]==("{1}"))&(item[1]["genero"]==("{2}"))), dic_copia.items()))'.format(j+1,region,genero ))
        exec('Grupo{0}=dict(sorted(Grupo{0}.items(), key =lambda x: -x[1]["promedio"]))'.format((j+1 )))

    if becas >len(lista_dist):
        num_registos=int(becas/len(lista_dist))
        for j in range(len(lista_dist)):

            for i in range(num_registos): 
                exec('estudiantes=len(Grupo{0})'.format(j+1))
                if estudiantes>0:
                    
                    exec('key=list(Grupo{0}.keys())[0]'.format(j+1))
                    exec('valores=list(Grupo{0}.values())[0]'.format(j+1))
                    exec('dic_grupo["{0}"]={1}'.format(key,valores))
                    exec('Grupo{0}.pop("{1}")'.format(j+1,key))
                    exec('dic_copia.pop("{0}")'.format(key))
                    becas=becas-1
                    if becas<1: break
            if becas<1: break
    else:
        for j in range(len(lista_dist)):
            
            exec('key=list(Grupo{0}.keys())[0]'.format(j+1))
            exec('valores=list(Grupo{0}.values())[0]'.format(j+1))
            exec('dic_grupo["{0}"]={1}'.format(key,valores))
            exec('Grupo{0}.pop("{1}")'.format(j+1,key))
            exec('dic_copia.pop("{0}")'.format(key))
            becas=becas-1
            if becas<1: break

dic_grupo
# Out:
# {'Estudiante_163': {'edad': 47.0,
#   'escolaridad': 'Secundaria',
#   'estado_civil': 'casada',
#   'estrato': 1.0,
#   'genero': 'masculino',
#   'promedio': 4.9,
#   'region': 'Andina'},
#  'Estudiante_395': {'edad': 69.0,
#   'escolaridad': 'Profesional',
#   'estado_civil': 'divorciada',
#   'estrato': 4.0,
#   'genero': 'masculino',
#   'promedio': 4.8,
#   'region': 'Andina'},
#  'Estudiante_10': {'edad': 80.0,
#   'escolaridad': 'Profesional',
#   'estado_civil': 'soltera',
#   'estrato': 3.0,
#   'genero': 'masculino',
#   'promedio': 4.5,
#   'region': 'Andina'},
#  'Estudiante_453': {'edad': 53.0,
#   'escolaridad': 'Secundaria',
#   'estado_civil': 'casada',
#   'estrato': 2.0,
#   'genero': 'masculino',
#   'promedio': 4.5,
#   'region': 'Andina'},
#  'Estudiante_223': {'edad': 34.0,
#   'escolaridad': 'Profesional',
#   'estado_civil': 'soltera',
#   'estrato': 2.0,
#   'genero': 'masculino',
#   'promedio': 4.4,
#   'region': 'Andina'},
# ...

# %% [markdown]
# **Misión 6**
#
# Desarrollar un algoritmo, a partir de lo anterior, cuyo resultado permita al comité comparar fácilmente las características de las dos poblaciones hipotéticas que recibirían becas.
#
# *Ayuda*: considera utilizar tus implementaciones de la *Misión 2* para facilitar esta misión.

# %%
# Resumen de la aplicación del modelo bajo las condiciones del primer grupo (estrato y promedio)#
import statistics
import numpy as np

keys_Estrato=list(dic_estrato.keys())
keys_Estrato[0]
Edad_Estrato=[]
for i in range (len(keys_Estrato)):
    Edad_Estrato.append(dic_estrato[keys_Estrato[i]]['edad'])

keys_Estrato=list(dic_estrato.keys())
keys_Estrato[0]
Promedio_Estrato=[]
for i in range (len(keys_Estrato)):
       Promedio_Estrato.append(dic_estrato[keys_Estrato[i]]['promedio'])
    
keys_Estrato=list(dic_estrato.keys())
keys_Estrato[0]
Estrato_Estrato=[]
for i in range (len(keys_Estrato)):
    Estrato_Estrato.append(dic_estrato[keys_Estrato[i]]['estrato'])

keys_Estrato=list(dic_estrato.keys())
keys_Estrato[0]
Genero_Estrato=[]
for i in range (len(keys_Estrato)):
    Genero_Estrato.append(dic_estrato[keys_Estrato[i]]['genero'])

keys_Estrato=list(dic_estrato.keys())
keys_Estrato[0]
Region_Estrato=[]
for i in range (len(keys_Estrato)):
    Region_Estrato.append(dic_estrato[keys_Estrato[i]]['region'])
    
keys_Estrato=list(dic_estrato.keys())
keys_Estrato[0]
Escolaridad_Estrato=[]
for i in range (len(keys_Estrato)):
    Escolaridad_Estrato.append(dic_estrato[keys_Estrato[i]]['escolaridad'])
    
    
keys_Estrato=list(dic_estrato.keys())
keys_Estrato[0]
Estado_Civil_Estrato=[]
for i in range (len(keys_Estrato)):
    Estado_Civil_Estrato.append(dic_estrato[keys_Estrato[i]]['estado_civil'])
    
count_datos=len(Edad_Estrato)
print ("La base de datos de becas asignadas en el Primer Grupo cuenta con : " + str(count_datos) + " registros")

median_edad=statistics.median(Edad_Estrato)
median_promedio=statistics.median(Promedio_Estrato)
median_estrato=statistics.median(Estrato_Estrato)
print ("Mediana de la edad: " + str(median_edad) + " Mediana Promedio: "+str(median_promedio) + " Mediana estrato: "+str(median_estrato))

mean_edad=statistics.mean(Edad_Estrato)
mean_promedio=statistics.mean(Promedio_Estrato)
mean_estrato=statistics.mean(Estrato_Estrato)
print ("Media de la edad del primer grupo modelo: " + str(mean_edad) + " Media Promedio del primer grupo modelo: "+str(mean_promedio) + " Media estrato del primer grupo modelo: "+str(mean_estrato))

st_edad=statistics.stdev(Edad_Estrato)
st_promedio=statistics.stdev(Promedio_Estrato)
st_estrato=statistics.stdev(Estrato_Estrato)
print ("Desviación estandar de la edad del primer grupo modelo: " + str(round(st_edad,3)) + " Desviación estandar Promedio del primer grupo modelo: "+str(round(st_promedio,3)) + " Desviación estandar estrato del primer grupo modelo: "+str(round(st_promedio,3)))

import matplotlib.pyplot as plt
#Edad vs Promedio
fig, ax = plt.subplots()
ax.scatter(Edad_Estrato, Promedio_Estrato)
ax.set_xscale('linear')                               # Establecemos una escala lineal para el eje x.
ax.set_yscale('linear')                               # Establecemos una escala lineal para el eje y.
ax.set_title('Gráfico de dispersión Edad vs. Promedio-PrimerGrupo')                 # Definimos un título para la visualización.
ax.grid(True)                                         # Agregamos una grilla al gráfico.
plt.show()


#Histograma de conteo por causales Edad
plt.style.use('ggplot')
plt.hist(Edad_Estrato, color="darkorange")
plt.title("Frecuencia según edad-Primer Grupo")
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales escolaridad
plt.style.use('ggplot')
plt.hist(Escolaridad_Estrato, color="red")
plt.title("Frecuencia según grado de escolaridad-Primer Grupo")
plt.xlabel('Escolaridad')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales estado civil
plt.style.use('ggplot')
plt.hist(Estado_Civil_Estrato, color="green")
plt.title("Frecuencia según estado civil-Primer Grupo")
plt.xlabel('Estado civil')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales estrato
plt.style.use('ggplot')
plt.hist(Estrato_Estrato, color="black", rwidth=1.5)
plt.title("Frecuencia según estrato-Primer Grupo")
plt.xlabel('Estrato')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales genero
plt.style.use('ggplot')
plt.hist(Genero_Estrato, color="blue", rwidth=1.5)
plt.title("Frecuencia según género-Primer Grupo")
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por promedio
plt.style.use('ggplot')
plt.hist(Promedio_Estrato, color="red", rwidth=1.5)
plt.title("Frecuencia según promedio-Primer Grupo")
plt.xlabel('Promedio')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por promedio
plt.style.use('ggplot')
plt.hist(Region_Estrato, color="blueviolet", rwidth=1.5)
plt.title("Frecuencia según Región-Primer Grupo")
plt.xlabel('Región')
plt.ylabel('Frecuencia')
plt.show()

##Resumen Gerencial Segundo Grupo en Funcion de la region-genero y promedio#
keys_grupo=list(dic_grupo.keys())
keys_grupo[0]
Edad_grupo=[]
for i in range (len(keys_grupo)):
    Edad_grupo.append(dic_grupo[keys_grupo[i]]['edad'])

keys_grupo=list(dic_grupo.keys())
keys_grupo[0]
Promedio_grupo=[]
for i in range (len(keys_grupo)):
       Promedio_grupo.append(dic_grupo[keys_grupo[i]]['promedio'])
    
keys_grupo=list(dic_grupo.keys())
keys_grupo[0]
Estrato_grupo=[]
for i in range (len(keys_grupo)):
    Estrato_grupo.append(dic_grupo[keys_grupo[i]]['estrato'])

keys_grupo=list(dic_grupo.keys())
keys_grupo[0]
Genero_grupo=[]
for i in range (len(keys_grupo)):
    Genero_grupo.append(dic_grupo[keys_grupo[i]]['genero'])

keys_grupo=list(dic_grupo.keys())
keys_grupo[0]
Region_grupo=[]
for i in range (len(keys_grupo)):
    Region_grupo.append(dic_grupo[keys_grupo[i]]['region'])
    
keys_grupo=list(dic_grupo.keys())
keys_grupo[0]
Escolaridad_grupo=[]
for i in range (len(keys_grupo)):
    Escolaridad_grupo.append(dic_grupo[keys_grupo[i]]['escolaridad'])
    
    
keys_grupo=list(dic_grupo.keys())
keys_grupo[0]
Estado_Civil_grupo=[]
for i in range (len(keys_grupo)):
    Estado_Civil_grupo.append(dic_grupo[keys_grupo[i]]['estado_civil'])
    
count_datos=len(Edad_grupo)
print ("La base de datos de becas asignadas en el Segundo Grupo cuenta con : " + str(count_datos) + " registros")

median_edad=statistics.median(Edad_grupo)
median_promedio=statistics.median(Promedio_grupo)
median_estrato=statistics.median(Estrato_grupo)
print ("Mediana de la edad: " + str(median_edad) + " Mediana Promedio: "+str(median_promedio) + " Mediana estrato: "+str(median_estrato))

mean_edad=statistics.mean(Edad_grupo)
mean_promedio=statistics.mean(Promedio_grupo)
mean_estrato=statistics.mean(Estrato_grupo)
print ("Media de la edad del primer grupo modelo: " + str(mean_edad) + " Media Promedio del primer grupo modelo: "+str(mean_promedio) + " Media estrato del primer grupo modelo: "+str(mean_estrato))

st_edad=statistics.stdev(Edad_grupo)
st_promedio=statistics.stdev(Promedio_grupo)
st_estrato=statistics.stdev(Estrato_grupo)
print ("Desviación estandar de la edad del primer grupo modelo: " + str(round(st_edad,3)) + " Desviación estandar Promedio del primer grupo modelo: "+str(round(st_promedio,3)) + " Desviación estandar estrato del primer grupo modelo: "+str(round(st_promedio,3)))

import matplotlib.pyplot as plt
#Edad vs Promedio
fig, ax = plt.subplots()
ax.scatter(Edad_grupo, Promedio_grupo)
ax.set_xscale('linear')                               # Establecemos una escala lineal para el eje x.
ax.set_yscale('linear')                               # Establecemos una escala lineal para el eje y.
ax.set_title('Gráfico de dispersión Edad vs. Promedio-Segundo Grupo')                 # Definimos un título para la visualización.
ax.grid(True)                                         # Agregamos una grilla al gráfico.
plt.show()


#Histograma de conteo por causales Edad
plt.style.use('ggplot')
plt.hist(Edad_grupo, color="darkorange")
plt.title("Frecuencia según edad-Segundo Grupo")
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales escolaridad
plt.style.use('ggplot')
plt.hist(Escolaridad_grupo, color="red")
plt.title("Frecuencia según grado de escolaridad-Segundo Grupo")
plt.xlabel('Escolaridad')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales estado civil
plt.style.use('ggplot')
plt.hist(Estado_Civil_grupo, color="green")
plt.title("Frecuencia según estado civil-Segundo Grupo")
plt.xlabel('Estado civil')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales estrato
plt.style.use('ggplot')
plt.hist(Estrato_grupo, color="black", rwidth=1.5)
plt.title("Frecuencia según estrato-Segundo Grupo")
plt.xlabel('Estrato')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales genero
plt.style.use('ggplot')
plt.hist(Genero_grupo, color="blue", rwidth=1.5)
plt.title("Frecuencia según género-Segundo Grupo")
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por promedio
plt.style.use('ggplot')
plt.hist(Promedio_grupo, color="red", rwidth=1.5)
plt.title("Frecuencia según promedio-Segundo Grupo")
plt.xlabel('Promedio')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por promedio
plt.style.use('ggplot')
plt.hist(Region_grupo, color="blueviolet", rwidth=1.5)
plt.title("Frecuencia según Región-Segundo Grupo")
plt.xlabel('Región')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# La base de datos de becas asignadas en el Primer Grupo cuenta con : 100 registros
# Mediana de la edad: 53.5 Mediana Promedio: 4.0 Mediana estrato: 2.0
# Media de la edad del primer grupo modelo: 50.85 Media Promedio del primer grupo modelo: 4.054 Media estrato del primer grupo modelo: 2.1
# Desviación estandar de la edad del primer grupo modelo: 18.361 Desviación estandar Promedio del primer grupo modelo: 0.416 Desviación estandar estrato del primer grupo modelo: 0.416
# La base de datos de becas asignadas en el Segundo Grupo cuenta con : 100 registros
# Mediana de la edad: 53.0 Mediana Promedio: 3.95 Mediana estrato: 2.0
# Media de la edad del primer grupo modelo: 49.48 Media Promedio del primer grupo modelo: 3.574 Media estrato del primer grupo modelo: 2.29
# Desviación estandar de la edad del primer grupo modelo: 18.217 Desviación estandar Promedio del primer grupo modelo: 1.101 Desviación estandar estrato del primer grupo modelo: 1.101

# %% [markdown]
# ## 3. Desarrollo de una solución analítica
#
# Reconociendo la complejidad de este problema (que no permite reducirlo a una dicotomía) y viendo el potencial del análisis de datos para enriquecer la discusión y los insumos para tomar decisiones, el comité ha solicitado una herramienta analítica que les permita . Sus requerimientos son:
#
# * La herramienta debe permitir ingresar una política de selección de becados.
#     * Se debe poder elegir el rango de edad de los aspirantes.
#     * Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato, o a cada región (pero sólo debe elegirse uno de estos criterios).
# * La herramienta debe generar un resultado que permita al comité analizar las características de la población potencialmente elegida si se usara la política ingresada.
#
# **Misión 7**
#
# Desarrollar, a partir de lo construido hasta el momento, un algoritmo que permita cumplir con los requerimientos del comité.

# %%
# Algoritmo para ejecución del comité con parametros de entrada en el modelo#
becas=100

#Filtro de edad debe ingresar el limite inferior y superior a tener en cuenta en la variable edad_menor y edad_mayor 
edad_menor=0
edad_mayor=50
#Filtro categorizado en la cual en el campo variable debe indicar que variable desea tener en cuenta en el modelo
#y en el campo distribuciones debe indicar segun la variable que proporcion quiere asignar#

##### Distribución por Genero
#variable="genero"
#distribuciones=[('masculino',45), ('femenino', 45), ('no binario',8),('otro',2)]

##### Distribución por Región
#variable="region"
#distribuciones=[('Andina',40), ('Orinoquia', 10), ('Caribe', 30),('Amazonia',10),('Pacifica',10)]

##### Distribución por estrato
variable="estrato"
distribuciones=[(1,40), (2, 30), (3, 15),(4,10),(5,5)]

#Listar grupos
grupos_herramienta=[]
for (k,v) in alg.items():
    if not v[variable] in grupos_herramienta:grupos_herramienta.append(v[variable])         

#Revisar si alcanzan
global revision
revision_cantidad=True
for j in range(len(distribuciones)):
    item=distribuciones[j][0]
    num_registos=int(becas*(distribuciones[j][1]/(100)))
    if variable!="estrato":#Ajustar el nombre de la variable en funcion de la variable a elegir en el modelo
        exec('Grupo=dict(filter(lambda item: ((item[1]["{1}"]==("{2}"))&(item[1]["edad"]>({3}))&(item[1]["edad"]<({4}))), alg.items()))'.format(j+1,variable,item,edad_menor,edad_mayor))
    else:
        exec('Grupo=dict(filter(lambda item: ((item[1]["{1}"]==({2}))&(item[1]["edad"]>({3}))&(item[1]["edad"]<({4}))), alg.items()))'.format(j+1,variable,item,edad_menor,edad_mayor))
    exec('estudiantes=len(Grupo)'.format(j+1))
    if not estudiantes>num_registos:
        print ('No cuenta con los estudiantes suficientes para asignar becas al {} {}'.format(variable, item)+ ". Reformule su distribución")
        revision_cantidad=False

#Revisar porcentajes revision_cantidad=True
revision_procentaje=True
porcentaje=0
for j in range(len(distribuciones)):
    porcentaje+=distribuciones[j][1]
if porcentaje>100:
    print('Los porcentajes asignados son mayores al 100%')
    revision_procentaje=False
elif porcentaje<100:
    print('Los porcentajes asignados no alcanzan al 100%')
    revision_procentaje=False
            
#Listar grupos
dic_analitica={}
if ((revision_cantidad)&(revision_procentaje)):
           
    for j in range(len(distribuciones)):
        item=distribuciones[j][0]
        num_registos=int(becas*(distribuciones[j][1]/(100)))
        if variable!="estrato":
            exec('Grupo=dict(filter(lambda item: ((item[1]["{1}"]==("{2}"))&(item[1]["edad"]>({3}))&(item[1]["edad"]<({4}))), alg.items()))'.format(j+1,variable,item,edad_menor,edad_mayor))
        else:
            exec('Grupo=dict(filter(lambda item: ((item[1]["{1}"]==({2}))&(item[1]["edad"]>({3}))&(item[1]["edad"]<({4}))), alg.items()))'.format(j+1,variable,item,edad_menor,edad_mayor))

        for i in range(num_registos): 
            exec('key=list(Grupo.keys())[0]')
            exec('valores=list(Grupo.values())[0]')
            exec('dic_analitica["{0}"]={1}'.format(key,valores))
            exec('Grupo.pop("{1}")'.format(j+1,key))
   
    print(dic_analitica)
# Out:
# {'Estudiante_15': {'edad': 47.0, 'escolaridad': 'Secundaria', 'estado_civil': 'divorciada', 'estrato': 1.0, 'genero': 'no binario', 'promedio': 1.2, 'region': 'Pacifica'}, 'Estudiante_16': {'edad': 24.0, 'escolaridad': 'Secundaria', 'estado_civil': 'divorciada', 'estrato': 1.0, 'genero': 'femenino', 'promedio': 0.1, 'region': 'Pacifica'}, 'Estudiante_30': {'edad': 49.0, 'escolaridad': 'Secundaria', 'estado_civil': 'divorciada', 'estrato': 1.0, 'genero': 'femenino', 'promedio': 2.9, 'region': 'Andina'}, 'Estudiante_31': {'edad': 49.0, 'escolaridad': 'Secundaria', 'estado_civil': 'casada', 'estrato': 1.0, 'genero': 'femenino', 'promedio': 3.7, 'region': 'Caribe'}, 'Estudiante_40': {'edad': 30.0, 'escolaridad': 'Maestria', 'estado_civil': 'soltera', 'estrato': 1.0, 'genero': 'masculino', 'promedio': 2.1, 'region': 'Orinoquia'}, 'Estudiante_59': {'edad': 19.0, 'escolaridad': 'Secundaria', 'estado_civil': 'divorciada', 'estrato': 1.0, 'genero': 'masculino', 'promedio': 2.6, 'region': 'Ori
# ...

# %% [markdown]
# **Misión 8**
#
# Proponer, con base en tu propio uso de la herramienta, una política de ingreso que consideres apropiada dado el contexto proporcionado. Si lo crees adecuado, explica, máximo 500 caracteres, las virtudes de tu propuesta (esto puede estar soportado en los datos, o no).

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)
respuesta = 'Basados en el compromiso del programa de la Universidad de Los Andes de generar impacto en la sociedad a través de la asignación de becas con prioridad a los estudiantes de bajos recursos, propongo tener en cuenta las siguientes variables de selección: edad en el rango de 15 a 45 años y el estrato, con una asignación por proporciones del 40% para el estrato 1, el 30% para el estrato 2, el 15% para el estrato 3, el 13% para el estrato 4 y el 2% para el estrato 5, dando prioridad en la asignación a los mejores promedios de cada subpoblación.'

# %% [markdown]
# **Misión 9**
#
# Ejecutar el algoritmo desarrollado en la *Misión 7* sobre la política que sugieres proponer al comité. Explicar claramente tus conlusiones con el soporte de los resultados de la herramienta.

# %%
# Ejecución del modelo propuesto#
# Algoritmo para ejecución del comité con parametros de entrada en el modelo#
becas=100

#Filtro de edad debe ingresar el limite inferior y superior a tener en cuenta en la variable edad_menor y edad_mayor 
edad_menor=15
edad_mayor=45
#Filtro categorizado en la cual en el campo variable debe indicar que variable desea tener en cuenta en el modelo
#y en el campo distribuciones debe indicar segun la variable que proporcion quiere asignar#

##### Distribución por Genero
#variable="genero"
#distribuciones=[('masculino',45), ('femenino', 45), ('no binario',8),('otro',2)]

##### Distribución por Región
#variable="region"
#distribuciones=[('Andina',40), ('Orinoquia', 10), ('Caribe', 30),('Amazonia',10),('Pacifica',10)]

##### Distribución por estrato
variable="estrato"
distribuciones=[(1,40), (2, 30), (3, 15),(4,13),(5,2)]

#Listar grupos
grupos_herramienta=[]
for (k,v) in alg.items():
    if not v[variable] in grupos_herramienta:grupos_herramienta.append(v[variable])         

#Revisar si alcanzan
global revision
revision_cantidad=True
for j in range(len(distribuciones)):
    item=distribuciones[j][0]
    num_registos=int(becas*(distribuciones[j][1]/(100)))
    if variable!="estrato":#Ajustar el nombre de la variable en funcion de la variable a elegir en el modelo
        exec('Grupo=dict(filter(lambda item: ((item[1]["{1}"]==("{2}"))&(item[1]["edad"]>({3}))&(item[1]["edad"]<({4}))), alg.items()))'.format(j+1,variable,item,edad_menor,edad_mayor))
    else:
        exec('Grupo=dict(filter(lambda item: ((item[1]["{1}"]==({2}))&(item[1]["edad"]>({3}))&(item[1]["edad"]<({4}))), alg.items()))'.format(j+1,variable,item,edad_menor,edad_mayor))
    exec('estudiantes=len(Grupo)'.format(j+1))
    if not estudiantes>num_registos:
        print ('No cuenta con los estudiantes suficientes para asignar becas al {} {}'.format(variable, item)+ ". Reformule su distribución")
        revision_cantidad=False

#Revisar porcentajes revision_cantidad=True
revision_procentaje=True
porcentaje=0
for j in range(len(distribuciones)):
    porcentaje+=distribuciones[j][1]
if porcentaje>100:
    print('Los porcentajes asignados son mayores al 100%')
    revision_procentaje=False
elif porcentaje<100:
    print('Los porcentajes asignados no alcanzan al 100%')
    revision_procentaje=False
            
#Listar grupos
dic_Propuesta={}
if ((revision_cantidad)&(revision_procentaje)):
           
    for j in range(len(distribuciones)):
        item=distribuciones[j][0]
        num_registos=int(becas*(distribuciones[j][1]/(100)))
        if variable!="estrato":
            exec('Grupo=dict(filter(lambda item: ((item[1]["{1}"]==("{2}"))&(item[1]["edad"]>({3}))&(item[1]["edad"]<({4}))), alg.items()))'.format(j+1,variable,item,edad_menor,edad_mayor))
        else:
            exec('Grupo=dict(filter(lambda item: ((item[1]["{1}"]==({2}))&(item[1]["edad"]>({3}))&(item[1]["edad"]<({4}))), alg.items()))'.format(j+1,variable,item,edad_menor,edad_mayor))

        for i in range(num_registos): 
            exec('key=list(Grupo.keys())[0]')
            exec('valores=list(Grupo.values())[0]')
            exec('dic_Propuesta["{0}"]={1}'.format(key,valores))
            exec('Grupo.pop("{1}")'.format(j+1,key))
   

    #Resumen Gerencial Propuesta#

keys_Propuesta=list(dic_Propuesta.keys())
keys_Propuesta[0]
Edad_Propuesta=[]
for i in range (len(keys_Propuesta)):
    Edad_Propuesta.append(dic_Propuesta[keys_Propuesta[i]]['edad'])

keys_Propuesta=list(dic_Propuesta.keys())
keys_Propuesta[0]
Promedio_Propuesta=[]
for i in range (len(keys_Propuesta)):
       Promedio_Propuesta.append(dic_Propuesta[keys_Propuesta[i]]['promedio'])
    
keys_Propuesta=list(dic_Propuesta.keys())
keys_Propuesta[0]
Estrato_Propuesta=[]
for i in range (len(keys_Propuesta)):
    Estrato_Propuesta.append(dic_Propuesta[keys_Propuesta[i]]['estrato'])

keys_Propuesta=list(dic_Propuesta.keys())
keys_Propuesta[0]
Genero_Propuesta=[]
for i in range (len(keys_Propuesta)):
    Genero_Propuesta.append(dic_Propuesta[keys_Propuesta[i]]['genero'])

keys_Propuesta=list(dic_Propuesta.keys())
keys_Propuesta[0]
Region_Propuesta=[]
for i in range (len(keys_Propuesta)):
    Region_Propuesta.append(dic_Propuesta[keys_Propuesta[i]]['region'])
    
keys_Propuesta=list(dic_Propuesta.keys())
keys_Propuesta[0]
Escolaridad_Propuesta=[]
for i in range (len(keys_Propuesta)):
    Escolaridad_Propuesta.append(dic_Propuesta[keys_Propuesta[i]]['escolaridad'])
    
    
keys_Propuesta=list(dic_Propuesta.keys())
keys_Propuesta[0]
Estado_Civil_Propuesta=[]
for i in range (len(keys_Propuesta)):
    Estado_Civil_Propuesta.append(dic_Propuesta[keys_Propuesta[i]]['estado_civil'])
    
count_datos=len(Edad_Propuesta)
print ("La base de datos de becas asignadas de la  Propuesta cuenta con : " + str(count_datos) + " registros")

median_edad=statistics.median(Edad_Propuesta)
median_promedio=statistics.median(Promedio_Propuesta)
median_estrato=statistics.median(Estrato_Propuesta)
print ("Mediana de la edad: " + str(median_edad) + " Mediana Promedio: "+str(median_promedio) + " Mediana estrato: "+str(median_estrato))

mean_edad=statistics.mean(Edad_Propuesta)
mean_promedio=statistics.mean(Promedio_Propuesta)
mean_estrato=statistics.mean(Estrato_Propuesta)
print ("Media de la edad de la Propuesta: " + str(mean_edad) + " Media Promedio de la Propuesta: "+str(mean_promedio) + " Media estrato de la Propuesta: "+str(mean_estrato))

st_edad=statistics.stdev(Edad_Propuesta)
st_promedio=statistics.stdev(Promedio_Propuesta)
st_estrato=statistics.stdev(Estrato_Propuesta)
print ("Desviación estandar de la edad de la Propuesta: " + str(round(st_edad,3)) + " Desviación estandar Promedio de la Propuesta: "+str(round(st_promedio,3)) + " Desviación estandar estrato de la Propuesta: "+str(round(st_promedio,3)))

import matplotlib.pyplot as plt
#Edad vs Promedio
fig, ax = plt.subplots()
ax.scatter(Edad_Propuesta, Promedio_Propuesta)
ax.set_xscale('linear')                               # Establecemos una escala lineal para el eje x.
ax.set_yscale('linear')                               # Establecemos una escala lineal para el eje y.
ax.set_title('Gráfico de dispersión Edad vs. Promedio- Propuesta')                 # Definimos un título para la visualización.
ax.grid(True)                                         # Agregamos una grilla al gráfico.
plt.show()


#Histograma de conteo por causales Edad
plt.style.use('ggplot')
plt.hist(Edad_Propuesta, color="darkorange")
plt.title("Frecuencia según edad- Propuesta")
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales escolaridad
plt.style.use('ggplot')
plt.hist(Escolaridad_Propuesta, color="red")
plt.title("Frecuencia según grado de escolaridad- Propuesta")
plt.xlabel('Escolaridad')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales estado civil
plt.style.use('ggplot')
plt.hist(Estado_Civil_Propuesta, color="green")
plt.title("Frecuencia según estado civil- Propuesta")
plt.xlabel('Estado civil')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales estrato
plt.style.use('ggplot')
plt.hist(Estrato_Propuesta, color="black", rwidth=1.5)
plt.title("Frecuencia según estrato- Propuesta")
plt.xlabel('Estrato')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por causales genero
plt.style.use('ggplot')
plt.hist(Genero_Propuesta, color="blue", rwidth=1.5)
plt.title("Frecuencia según género- Propuesta")
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por promedio
plt.style.use('ggplot')
plt.hist(Promedio_Propuesta, color="red", rwidth=1.5)
plt.title("Frecuencia según promedio- Propuesta")
plt.xlabel('Promedio')
plt.ylabel('Frecuencia')
plt.show()
#Histograma de conteo por promedio
plt.style.use('ggplot')
plt.hist(Region_Propuesta, color="blueviolet", rwidth=1.5)
plt.title("Frecuencia según Región- Propuesta")
plt.xlabel('Región')
plt.ylabel('Frecuencia')
plt.show()

print("Conclusion: 'Bajo esta metodologia aunquen no se logra captar a los mejores promedios de toda la población si se logra asignar las becas a la población de bajos recursos, seleccionando a los mejores perfiles academicos de cada subpoblación'")
# Out:
# La base de datos de becas asignadas de la  Propuesta cuenta con : 100 registros
# Mediana de la edad: 30.0 Mediana Promedio: 2.3 Mediana estrato: 2.0
# Media de la edad de la Propuesta: 30.47 Media Promedio de la Propuesta: 2.345 Media estrato de la Propuesta: 2.07
# Desviación estandar de la edad de la Propuesta: 8.036 Desviación estandar Promedio de la Propuesta: 1.068 Desviación estandar estrato de la Propuesta: 1.068
# Conclusion: 'Bajo esta metodologia aunquen no se logra captar a los mejores promedios de toda la población si se logra asignar las becas a la población de bajos recursos, seleccionando a los mejores perfiles academicos de cada subpoblación'

# %% [markdown]
# ## Referencias
# * Discriminación Positiva<br>
# https://es.wikipedia.org/wiki/Discriminaci%C3%B3n_positiva
# * Análisis de formulación del programa “Ser Pilo Paga”<br>
# https://repository.urosario.edu.co/handle/10336/12526
# * La acción afirmativa en la Universidad de los Andes: El caso del programa "Oportunidades para talentos nacionales"<br> http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0123-885X2004000300005
# * Acción afirmativa y equidad: un análisis desde la propuesta de Thomas Nagel<br>
# http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2007-24062016000200049

# %% [markdown]
# ## Créditos

# %% [markdown]
# Camilo Gómez - 11/06/21<br>
# *Revisado*: 25/08/21
